# %% [markdown]
# # 1. Import the additional Libs

# %%
import pandas as pd
import requests
import lxml
from bs4 import BeautifulSoup
import time
import pyodbc
from urllib.error import URLError, HTTPError
from urllib.request import Request, urlopen
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime

# %% [markdown]
# # 2. Defining the standard Site Adresses

# %%
# Defining the header for the web get
user_agent = 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'
headers = {'User-Agent' : user_agent}

#year of test
year_actual = 2022
website_base = "https://fbref.com/"
website_table_results = website_base + "en/comps/22/"+str(year_actual)+"/"+str(year_actual)+"/Major-League-Soccer-Stats"

# %%
website_table_results
# Out:
# 'https://fbref.com/en/comps/22/2022/2022/Major-League-Soccer-Stats'

# %% [markdown]
# # 3. Creating Function to Extract the Data from the site

# %%
# Function to get content from website
def ConsultaWebB(url):
    try:
        req = Request(url, headers = headers)
        response = urlopen(req)
        return response.read()
    
    except:
        pass

# %%
# Function to get Ranking Table from website
def ConsultaWebB_SeasonDetail(rawFullTable_Year):
    
    # Reading the table result to get the link for each team in each conference (east/west)
    soup = BeautifulSoup(rawFullTable_Year)
    standings_table_east = soup.select('table.stats_table')[0]
    standings_table_west = soup.select('table.stats_table')[2]

    # Get the links for East Conference
    links_east = standings_table_east.find_all('a')
    links_east = [l.get("href") for l in links_east]
    links_east = [l for l in links_east if '/squads/' in l]

    # Get the links for West Conference
    links_west = standings_table_west.find_all('a')
    links_west = [l.get("href") for l in links_west]
    links_west = [l for l in links_west if '/squads/' in l]
    
    # Get each club link on the table
    links = links_west + links_east
    team_urls = [f"https://fbref.com{l}" for l in links]
        
    return team_urls

# %%
# Function to get Ranking Table from website
def ConsultaWebB_RkTable_links(year):
    
    #Define year and web address
    year_actual = year
    website_base = "https://fbref.com/"
    website_table_results = website_base + "en/comps/22/"+str(year_actual)+"/"+str(year_actual)+"/Major-League-Soccer-Stats"
    
    #Request
    raw_data = ConsultaWebB(website_table_results)
    
    # Getting the Table of Results
    FullTable_EastConf = pd.read_html(raw_data)[0]
    FullTable_WestConf = pd.read_html(raw_data)[2]
    
    ################################ CONFERENCE
    FullTable_EastConf['Conference'] = 'EastConf'
    FullTable_WestConf['Conference'] = 'WestConf'
    
    FullTable_Year = pd.concat([FullTable_EastConf,FullTable_WestConf])
    FullTable_Year["Season"] = year_actual
    
    #using the function to get urls
    team_urls = ConsultaWebB_SeasonDetail(raw_data)
    
    return FullTable_Year, team_urls

# %%
# Function to get Ranking Table from website
def ConsultaWebB_RkTable_details(links, actual_year):

    # Creating a DF from details of each team
    match_details = pd.DataFrame()
    for link in links:
        raw_data = ConsultaWebB(link)
        matches_det = pd.read_html(raw_data, match="Scores & Fixtures")[0]
        matches_det["Season"] = actual_year
        matches_det["Team"] = link.split('/')[-1][:-6]

        match_details = pd.concat([match_details,matches_det])

        time.sleep(1)
        
    match_details = match_details[match_details['Round']=='Regular Season']
    
    return match_details

# %% [markdown]
# # 4. Creating SQL Functions to Query, Insert and Truncate tables

# %%
# Function Select
def SQLSelect(query):
    conn = pyodbc.connect('Trusted_Connection=yes',
                      driver = '{ODBC Driver 17 for SQL Server}',
                      server = 'localhost',
                      database = 'MLS_Project')
    out = pd.read_sql_query(query,conn)
    return out

query_all_rank = '''
    Select 
    * 
    from TableRankBase
'''
query_all_details = '''
    Select 
    * 
    from TableDetailsBase
'''
query_max_rank = '''
    SELECT
        maior = max(Proposicao)
    from TableDetailsBase
'''
query_max_details = '''
    SELECT
        maior = max(Proposicao)
    from TableDetailsBase
'''

# %%
# Function to truncate a table
def SQLTruncate(TableName):
    conn = pyodbc.connect('Trusted_Connection=yes',
                          driver = '{ODBC Driver 17 for SQL Server}',
                          server = 'localhost',
                          database = 'MLS_Project')

    cursor = conn.cursor()

    cursor.execute(f'''
    
                   TRUNCATE TABLE {TableName}
                     
                   ''')
    conn.commit()
    cursor.close()

# %%
# Create a function to INSERT Table of Ranking
def SQLInsertRanking(TableRanking):
    base = pd.DataFrame(columns=['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
                                 'xG', 'xGA', 'xGD', 'xGD/90', 'Attendance', 'Top Team Scorer',
                                 'Goalkeeper', 'Notes', 'Conference', 'Season'])
    TableBase = base.append(TableRanking).fillna('')

    conn = pyodbc.connect('Trusted_Connection=yes',
                          driver = '{ODBC Driver 17 for SQL Server}',
                          server = 'localhost',
                          database = 'MLS_Project')

    cursor = conn.cursor()

    for index, row in TableBase.iterrows():

        cursor.execute('''

            INSERT INTO TableRankBase (
                Rk, 
                TEAM_NAME, 
                MP, 
                W, 
                D, 
                L, 
                GF, 
                GA, 
                GD, 
                PTS, 
                PTS_MP,
                XG, 
                XGA, 
                XGD, 
                XGD_90, 
                NOTES,
                CONFERENCE,
                SEASON

            )
            Values(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)''', # mesma qtde de variaveis

            row['Rk'],
            row['Squad'],
            row['MP'],
            row['W'],
            row['D'],
            row['L'],
            row['GF'],
            row['GA'],
            row['GD'],
            row['Pts'],           
            row['Pts/MP'],           
            row['xG'],           
            row['xGA'],           
            row['xGD'],           
            row['xGD/90'],           
            row['Notes'],           
            row['Conference'], 
            row['Season']
        )

    conn.commit()
    cursor.close()

# %%
# Create a function to INSERT Table of Details
def SQLInsertGameDetails(TableGameDetails):
    base = pd.DataFrame(columns=['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
                                 'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
                                 'Referee', 'Match Report', 'Notes', 'Season', 'Team'])
    TableBase = base.append(TableGameDetails).fillna('')

    conn = pyodbc.connect('Trusted_Connection=yes',
                          driver = '{ODBC Driver 17 for SQL Server}',
                          server = 'localhost',
                          database = 'MLS_Project')

    cursor = conn.cursor()

    for index, row in TableBase.iterrows():

        cursor.execute('''

            INSERT INTO TableDetailsBase ( 
                TEAM_NAME, 
                GAME_Date,
                GAME_Time,
                Comp,
                SEASON_Round,
                WEEK_DAY,
                TEAM_Venue,
                GAME_Result,
                GF,
                GA,
                Opponent,
                xG,
                xGA,
                Poss,
                Attendance,
                Captain,
                Formation,
                Referee,
                Notes,
                Season

            )
            Values(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)''', # mesma qtde de variaveis

            row['Team'],
            row['Date'],
            row['Time'],
            row['Comp'],
            row['Round'],
            row['Day'],
            row['Venue'],
            row['Result'],
            row['GF'],
            row['GA'],           
            row['Opponent'],           
            row['xG'],           
            row['xGA'],           
            row['Poss'],           
            row['Attendance'],           
            row['Captain'],           
            row['Formation'],
            row['Referee'],
            row['Notes'], 
            row['Season']
        )

    conn.commit()
    cursor.close()

# %% [markdown]
# # 5. Function GetInsert toguether all Function

# %%
def GetInsertAllData(year):
    
    #Getting data from year (Ranking table and details link)
    FullTable_Year_df, team_urls_list = ConsultaWebB_RkTable_links(year)
    
    #Insert data into SQL - Table Rank
    SQLInsertRanking(FullTable_Year_df)
    print('Total of ' + str(len(FullTable_Year_df)) + ' inserted on the database Rank.')
    
    #Getting Teams season details
    FullTable_Year_details = ConsultaWebB_RkTable_details(team_urls_list, year)
    
    #Insert data into SQL - Table Details
    SQLInsertGameDetails(FullTable_Year_details)
    print('Total of ' + str(len(FullTable_Year_details)) + ' inserted on the database Season details.')

# %% [markdown]
# # 6. Testing

# %%
SQLTruncate('TableDetailsBase')
SQLTruncate('TableRankBase')

# %%
GetInsertAllData(2022)
# Out:
# Total of 28 inserted on the database Rank.
# Total of 952 inserted on the database Season details.

# %%
table_rank = SQLSelect(query_all_rank)
table_rank_details = SQLSelect(query_all_details)

# %%
table_rank
# Out:
#      Generalkey  Rk        TEAM_NAME  MP   W  D   L  GF  GA  GD  PTS  PTS_MP  \
# 0             1   1     Philadelphia  23  14  5   4  44  20  24   47    2.04
# 1             2   2       Toronto FC  23  13  5   5  33  26   7   44    1.91
# 2             3   3    Columbus Crew  23  12  5   6  36  21  15   41    1.78
# 3             4   4     Orlando City  23  11  8   4  40  25  15   41    1.78
# 4             5   5            NYCFC  23  12  3   8  37  25  12   39    1.70
# ..          ...  ..              ...  ..  .. ..  ..  ..  ..  ..  ...     ...
# 185         186   8        Vancouver  34  13  8  13  54  67 -13   47    1.38
# 186         187   9   Houston Dynamo  34  10  8  16  58  58   0   38    1.12
# 187         188  10    Minnesota Utd  34  11  3  20  49  71 -22   36    1.06
# 188         189  11  Colorado Rapids  34   8  7  19  36  63 -27   31    0.91
# 189         190  12         San Jose  34   4  9  21  49  71 -22   21    0.62
#
#        XG   XGA   XGD  XGD_90          NOTES CONFERENCE  SEASON
# 0    35.0  23.5  11.4    0.57  ? First Round   EastConf    2020
# 1    31.1  22.5   8.6    0.43  ? First Round   EastConf    2020
# 2    28.6  28.1   0.5    0.03  ? First Round   EastConf    2020
# 3    27.5  24.3   3.2    0.16  ? First Round   EastConf    2020
# 4    33.3  26.7   6.7    0.33  ? First Round   EastConf    2020
# ..    ...   ...   ...     ...            ...        ...     ...
# 185  52.8  60.3  -7.5   -0.22                  WestConf    2018
# 186  56.8  55.3   1.6    0.05                  WestConf    2018
# 187  48.1  61.4 -13.2   -0.39                  WestConf    2018
# 188  40.4  61.4 -21.0   -0.62                  WestConf    2018
# 189  43.0  60.0 -17.0   -0.50                  WestConf    2018
#
# [190 rows x 19 columns]

# %%
table_rank_details
# Out:
#      Generalkey       TEAM_NAME   GAME_Date GAME_Time Comp    SEASON_Round  \
# 0             1  Los-Angeles-FC  2022-02-26  12:30:00  MLS  Regular Season
# 1             2  Los-Angeles-FC  2022-03-06  19:00:00  MLS  Regular Season
# 2             3  Los-Angeles-FC  2022-03-12  13:30:00  MLS  Regular Season
# 3             4  Los-Angeles-FC  2022-03-20  19:00:00  MLS  Regular Season
# 4             5  Los-Angeles-FC  2022-04-02  19:30:00  MLS  Regular Season
# ..          ...             ...         ...       ...  ...             ...
# 947         948       DC-United  2022-09-10  19:30:00  MLS  Regular Season
# 948         949       DC-United  2022-09-13  19:30:00  MLS  Regular Season
# 949         950       DC-United  2022-09-18  17:00:00  MLS  Regular Season
# 950         951       DC-United  2022-10-01  19:30:00  MLS  Regular Season
# 951         952       DC-United  2022-10-09  14:30:00  MLS  Regular Season
#
#     WEEK_DAY TEAM_Venue GAME_Result  GF  ...          Opponent   xG  xGA  \
# 0        Sat       Home           W   3  ...   Colorado Rapids  2.4  0.4
# 1        Sun       Home           D   1  ...  Portland Timbers  2.2  0.6
# 2        Sat       Away           W   2  ...       Inter Miami  0.5  0.4
# 3        Sun       Home           W   3  ...         Vancouver  1.7  1.1
# 4        Sat       Away           W   4  ...      Orlando City  2.7  1.4
# ..       ...        ...         ...  ..  ...               ...  ...  ...
# 947      Sat       Away           D   0  ...    Real Salt Lake  0.6  0.5
# 948      Tue       Away           L   0  ...       Sporting KC  0.4  1.9
# 949      Sun       Home           L   2  ...       Inter Miami  0.8  1.2
# 950      Sat       Away           L   0  ...       CF Montréal  0.6  2.0
# 951      Sun       Home           L   2  ...     FC Cincinnati  0.4  2.1
#
#      Poss  Attendance         Captain Formation             Referee Notes  \
# 0      51     22010.0     Carlos Vela     4-3-3  Armando Villarreal
# 1      69     22102.0     Carlos Vela     4-3-3       Ismail Elfath
# 2      53     11465.0     Carlos Vela     4-3-3           Ted Unkel
# 3      62     22065.0     Carlos Vela     4-3-3      Guido Gonzalez
# 4      39     16753.0     Carlos Vela     4-3-3       Joe Dickerson
# ..    ...         ...             ...       ...                 ...   ...
# 947    44     20487.0  Victor Pálsson     3-5-2      Kevin Broadley
# 948    41     15106.0  Steve Birnbaum     4-4-2          R. Mendoza
# 949    43     14284.0  Steve Birnbaum   4-2-3-1       Ismail Elfath
# 950    36     19619.0  Steve Birnbaum   4-2-3-1        Ramy Touchan
# 951    57     19325.0  Steve Birnbaum     4-3-3            Tim Ford
#
#     Season
# 0     2022
# 1     2022
# 2     2022
# 3     2022
# 4     2022
# ..     ...
# 947   2022
# 948   2022
# 949   2022
# 950   2022
# 951   2022
#
# [952 rows x 21 columns]

# %% [markdown]
# # 7. Inserting Data from 2015 to 2022

# %%
# Defining inital and end year
first_year = 2015
last_year = 2022

#Starting process
print("###################### Process started at ", datetime.now().strftime("%d/%m/%Y %H:%M:%S"))
# Truncate the tables
SQLTruncate('TableDetailsBase')
SQLTruncate('TableRankBase')

# Running the function for each year
for i in list(range(first_year, last_year+1)):
    print('Starting get data from year: ',i,' at', datetime.now().strftime("%d/%m/%Y %H:%M:%S"))
    try:
        GetInsertAllData(i)
        time.sleep(2)
        
    except:
        pass
print("###################### Insert all done at", datetime.now().strftime("%d/%m/%Y %H:%M:%S"))

# %%
table_rank = SQLSelect(query_all_rank)
table_rank_details = SQLSelect(query_all_details)

# %%
table_rank
# Out:
#      Generalkey  Rk        TEAM_NAME  MP   W  D   L  GF  GA  GD  PTS  PTS_MP  \
# 0             1   1     Philadelphia  23  14  5   4  44  20  24   47    2.04
# 1             2   2       Toronto FC  23  13  5   5  33  26   7   44    1.91
# 2             3   3    Columbus Crew  23  12  5   6  36  21  15   41    1.78
# 3             4   4     Orlando City  23  11  8   4  40  25  15   41    1.78
# 4             5   5            NYCFC  23  12  3   8  37  25  12   39    1.70
# ..          ...  ..              ...  ..  .. ..  ..  ..  ..  ..  ...     ...
# 185         186   8        Vancouver  34  13  8  13  54  67 -13   47    1.38
# 186         187   9   Houston Dynamo  34  10  8  16  58  58   0   38    1.12
# 187         188  10    Minnesota Utd  34  11  3  20  49  71 -22   36    1.06
# 188         189  11  Colorado Rapids  34   8  7  19  36  63 -27   31    0.91
# 189         190  12         San Jose  34   4  9  21  49  71 -22   21    0.62
#
#        XG   XGA   XGD  XGD_90          NOTES CONFERENCE  SEASON
# 0    35.0  23.5  11.4    0.57  ? First Round   EastConf    2020
# 1    31.1  22.5   8.6    0.43  ? First Round   EastConf    2020
# 2    28.6  28.1   0.5    0.03  ? First Round   EastConf    2020
# 3    27.5  24.3   3.2    0.16  ? First Round   EastConf    2020
# 4    33.3  26.7   6.7    0.33  ? First Round   EastConf    2020
# ..    ...   ...   ...     ...            ...        ...     ...
# 185  52.8  60.3  -7.5   -0.22                  WestConf    2018
# 186  56.8  55.3   1.6    0.05                  WestConf    2018
# 187  48.1  61.4 -13.2   -0.39                  WestConf    2018
# 188  40.4  61.4 -21.0   -0.62                  WestConf    2018
# 189  43.0  60.0 -17.0   -0.50                  WestConf    2018
#
# [190 rows x 19 columns]

# %%
table_rank_details
# Out:
#       Generalkey     TEAM_NAME   GAME_Date GAME_Time Comp    SEASON_Round  \
# 0              1   Sporting-KC  2020-02-29  19:30:00  MLS  Regular Season
# 1              2   Sporting-KC  2020-03-07  19:30:00  MLS  Regular Season
# 2              3   Sporting-KC  2020-08-21  18:30:00  MLS  Regular Season
# 3              4   Sporting-KC  2020-08-25  19:30:00  MLS  Regular Season
# 4              5   Sporting-KC  2020-08-29  19:00:00  MLS  Regular Season
# ...          ...           ...         ...       ...  ...             ...
# 6085        6086  Orlando-City  2018-10-06  19:00:00  MLS  Regular Season
# 6086        6087  Orlando-City  2018-10-13  19:30:00  MLS  Regular Season
# 6087        6088  Orlando-City  2018-10-17  19:30:00  MLS  Regular Season
# 6088        6089  Orlando-City  2018-10-21  15:00:00  MLS  Regular Season
# 6089        6090  Orlando-City  2018-10-28  16:30:00  MLS  Regular Season
#
#      WEEK_DAY TEAM_Venue GAME_Result  GF  ...         Opponent   xG  xGA  \
# 0         Sat       Away           W   3  ...        Vancouver  0.5  2.2
# 1         Sat       Home           W   4  ...   Houston Dynamo  2.6  0.7
# 2         Fri       Away           W   2  ...    Minnesota Utd  0.9  0.9
# 3         Tue       Home           L   2  ...   Houston Dynamo  2.2  2.6
# 4         Sat       Away           D   1  ...  Colorado Rapids  0.6  1.2
# ...       ...        ...         ...  ..  ...              ...  ...  ...
# 6085      Sat       Away           L   0  ...        FC Dallas  0.5  0.8
# 6086      Sat       Away           L   0  ...      New England  0.5  1.6
# 6087      Wed       Home           L   1  ...          Seattle  1.1  1.6
# 6088      Sun       Home           W   2  ...    Columbus Crew  2.2  0.5
# 6089      Sun       Away           L   0  ...     NY Red Bulls  0.8  1.5
#
#       Poss  Attendance         Captain Formation             Referee Notes  \
# 0       52     22120.0     Matt Besler     4-3-3           Ted Unkel
# 1       56     21188.0     Matt Besler     4-3-3       Allen Chapman
# 2       42         0.0     Alan Pulido     4-3-3        Ramy Touchan
# 3       49         0.0     Alan Pulido   4-1-4-1       Joe Dickerson
# 4       38         0.0     Alan Pulido   4-1-4-1  Armando Villarreal
# ...    ...         ...             ...       ...                 ...   ...
# 6085    48     16519.0  Sacha Kljestan   4-2-3-1        Nima Saghafi
# 6086    40     19775.0     Lamine Sané     5-4-1        David Gantar
# 6087    54     22344.0  Sacha Kljestan   4-2-3-1         Mark Geiger
# 6088    50     23642.0  Sacha Kljestan     3-4-3         Kevin Stott
# 6089    54     20023.0  Sacha Kljestan     5-4-1       Ismail Elfath
#
#      Season
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
# ...     ...
# 6085   2018
# 6086   2018
# 6087   2018
# 6088   2018
# 6089   2018
#
# [6090 rows x 21 columns]

# %% [markdown]
# # 8. Plots and Descriptive Analysis

# %% [markdown]
# # 9. Data Cleaning (removing duplicates)

# %% [markdown]
# # 10. Inserting cleaned tables to the Database
